# %%
import pandas as pd
from sqlalchemy import create_engine
# MySQL database connection details
host = '10.233.209.2'
user = 'usr_sectidf'
password = 'DHS-14z4'
port = 3306
database = 'db_sectidf'

# Create a SQLAlchemy engine
engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}')

servidores = pd.read_sql_table('servidores', engine)
projetos = pd.read_sql_table('Projetos', engine)
ProjetoParceiros = pd.read_sql_table('ProjetoParceiros', engine)

# %%
servidores.to_csv('servidores.csv', index=False)

# %%
from pandas import read_csv


servidores2 = read_csv('teste.csv')

# %%
servidores2
# Out:
#                   Nome Matricula  \
# 0       LEONARDO SOCHA  02836939
# 1         RENATO ROCHA  02829339
# 2     ODIRLEY DE JESUS  02824108
# 3      MARIANA MOREIRA  02797976
# 4       MICHELE CAMPOS  02824744
# ..                 ...       ...
# 71       ANDRESSA JUCA  02828421
# 72    EDIMILSON ARRUDA  02828111
# 73      LUCAS CANDEIRA  02738929
# 74  PATRICIA DE ARAGAO  02834839
# 75      VALDIR CARDOSO  0282812X
#
#                                    Unidade de Lotação
# 0              41.00.00.00.00.00-SECRETÁRIO DE ESTADO
# 1                         41.01.00.00.00.00- Gabinete
# 2                         41.01.00.00.00.00- Gabinete
# 3                         41.01.00.00.00.00- Gabinete
# 4   41.01.04.00.00.00Assessoria de Gestão Estr. de...
# ..                                                ...
# 71  41.30.10.00.00.00   Diretoria de Dif. Cientifi...
# 72  41.30.10.20.00.00   Gerência de Pesquisa e Ret...
# 73  41.30.20.00.00.00   Diretoria de Economia Circ...
# ...

# %%
# Converte as listas para DataFrames
df1 = pd.DataFrame(servidores, columns=['Nome'])
df2 = pd.DataFrame(servidores2, columns=['Nome'])

# %%
for nome in df2['Nome']:
    df1[nome] = df1['Nome'].str.contains(nome)

# %%
df1
# Out:
#                                    Nome  LEONARDO SOCHA  RENATO ROCHA  \
# 0                                     0           False         False
# 1            Altamiro Pereira F. Junior           False         False
# 2            Ana Clara Tavares da Silva           False         False
# 3       Ana Paula Almeida Aragão(FAPDF)           False         False
# 4        Bruna Petrnylla Gomes de Sousa           False         False
# 5                           Bruno Frota           False         False
# 6       Bruno Limeira Teixeira Pinheiro           False         False
# 7       Bruno Mariano Souza Lopes Frota           False         False
# 8         Cássia Eduarda Alves Barcelos           False         False
# 9         Cássia Fonseca Campos Antunes           False         False
# 10                        Daniel Amorim           False         False
# 11               Davi Ferreira da Costa           False         False
# ...
